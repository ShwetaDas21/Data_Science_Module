# %%
import pandas as pd

# %% [markdown]
# ##### Series

# %%
s = pd.Series([56,32,14,37,48,71,94])

# %%
s
# Out:
# 0    56
# 1    32
# 2    14
# 3    37
# 4    48
# 5    71
# 6    94
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.ndim, s.shape , s.size
# Out:
# (1, (7,), 7)

# %% [markdown]
# #### DataFrame

# %%
r = pd.Series([1,2,3,4,5])
n = pd.Series(['Akash','Anita','Prem','Raj','Shekhar'])
m = pd.Series([56.78,89.56,67.87,76.78,69.87])

# %%
df = pd.DataFrame({'roll' : r, 'name:' : n, 'marks': m})

# %%
df
# Out:
#    roll    name:  marks
# 0     1    Akash  56.78
# 1     2    Anita  89.56
# 2     3     Prem  67.87
# 3     4      Raj  76.78
# 4     5  Shekhar  69.87

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# roll       int64
# name:     object
# marks    float64
# dtype: object

# %%
df.shape
# Out:
# (5, 3)

# %%
df.columns
# Out:
# Index(['roll', 'name:', 'marks'], dtype='object')

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HP'

# %%
### Location of File https://mitu.co.in/dataset
### Download all the files, names start with student
# and store in current working directory

# %%
df = pd.read_csv('student.csv')
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df1 = pd.read_csv("student1.csv",  names=['A','B','C','D','E']) #####We can title the headers
df1
# Out:
#     A        B   C      D   E
# 0   1     anil  TE  56.77  22
# 1   2     amit  TE  59.77  21
# 2   3   aniket  BE  76.88  19
# 3   4  ajinkya  TE  69.66  20
# 4   5     asha  TE  63.28  20
# 5   6   ayesha  BE  49.55  20
# 6   7     amar  BE  65.34  19
# 7   8    amita  BE  68.33  23
# 8   9     amol  TE  56.75  20
# 9  10    anmol  BE  78.66  21

# %%
df3 = pd.read_csv("student3.tsv")
df3
# Out:
#   roll\tname\tclass\tmarks\tage
# 0        1\tanil\tTE\t56.77\t22
# 1        2\tamit\tTE\t59.77\t21
# 2      3\taniket\tBE\t76.88\t19
# 3     4\tajinkya\tTE\t69.66\t20
# 4        5\tasha\tTE\t63.28\t20
# 5      6\tayesha\tBE\t49.55\t20
# 6        7\tamar\tBE\t65.34\t19
# 7       8\tamita\tBE\t68.33\t23
# 8        9\tamol\tTE\t56.75\t20
# 9      10\tanmol\tBE\t78.66\t21

# %%
df3 = pd.read_csv("student3.tsv", sep='\t')  ####by default , is the separator sep is separator
df3
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df3.columns = ['roll','full_name','class','marks','age']

# %%
df3
# Out:
#    roll full_name class  marks  age
# 0     1      anil    TE  56.77   22
# 1     2      amit    TE  59.77   21
# 2     3    aniket    BE  76.88   19
# 3     4   ajinkya    TE  69.66   20
# 4     5      asha    TE  63.28   20
# 5     6    ayesha    BE  49.55   20
# 6     7      amar    BE  65.34   19
# 7     8     amita    BE  68.33   23
# 8     9      amol    TE  56.75   20
# 9    10     anmol    BE  78.66   21

# %%
df.head()    ###by default parameter is 5
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df.tail()   #### Default parameter is 5
# Out:
#    roll    name class  marks  age
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %% [markdown]
# ##### Slicing

# %%
df.iloc[2:8,1:4]   #### iloc = index location, higher bound is always -1
# Out:
#       name class  marks
# 2   aniket    BE  76.88
# 3  ajinkya    TE  69.66
# 4     asha    TE  63.28
# 5   ayesha    BE  49.55
# 6     amar    BE  65.34
# 7    amita    BE  68.33

# %%
df.iloc[:, :]
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.loc[:,'name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.loc[:,['name','marks']]
# Out:
#       name  marks
# 0     anil  56.77
# 1     amit  59.77
# 2   aniket  76.88
# 3  ajinkya  69.66
# 4     asha  63.28
# 5   ayesha  49.55
# 6     amar  65.34
# 7    amita  68.33
# 8     amol  56.75
# 9    anmol  78.66

# %%
df[['name','marks']]
# Out:
#       name  marks
# 0     anil  56.77
# 1     amit  59.77
# 2   aniket  76.88
# 3  ajinkya  69.66
# 4     asha  63.28
# 5   ayesha  49.55
# 6     amar  65.34
# 7    amita  68.33
# 8     amol  56.75
# 9    anmol  78.66

# %%
df.name ###this works for all rows but only column, This acts like an attribute
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.name[1]
# Out:
# 'amit'

# %%
df.iloc[range(1,11,2),:]
# Out:
#    roll     name class  marks  age
# 1     2     amit    TE  59.77   21
# 3     4  ajinkya    TE  69.66   20
# 5     6   ayesha    BE  49.55   20
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21

# %%
import numpy as np

# %%
num = [np.random.randint(1,10) for x in range(5)]
num
# Out:
# [3, 4, 7, 9, 7]

# %%
df.iloc[num,:]
# Out:
#    roll     name class  marks  age
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21
# 7     8    amita    BE  68.33   23

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df.drop(5)
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.name[2]
# Out:
# 'Ashutosh'

# %%
df3 = pd.read_csv('student3.csv')

# %%
df3['age']
# Out:
# 0     22.0
# 1     21.0
# 2     19.0
# 3     20.0
# 4      NaN
# 5     20.0
# 6     19.0
# 7     23.0
# 8     20.0
# 9     20.0
# 10     NaN
# 11    23.0
# 12    22.0
# 13    21.0
# 14    21.0
# 15    20.0
# Name: age, dtype: float64

# %%
df3['age'].fillna(20)
# Out:
# 0     22.0
# 1     21.0
# 2     19.0
# 3     20.0
# 4     20.0
# 5     20.0
# 6     19.0
# 7     23.0
# 8     20.0
# 9     20.0
# 10    20.0
# 11    23.0
# 12    22.0
# 13    21.0
# 14    21.0
# 15    20.0
# Name: age, dtype: float64

# %%
#### isnull() function to check NaN values
df.drop([4,6,7])   #### This works by default on rows
# Out:
#    roll      name class  marks  age
# 0     1      anil    TE  56.77   22
# 1     2      amit    TE  59.77   21
# 2     3  Ashutosh    BE  76.88   19
# 3     4   ajinkya    TE  69.66   20
# 5     6    ayesha    BE  49.55   20
# 8     9      amol    TE  56.75   20
# 9    10     anmol    BE  78.66   21

# %%
df.drop('class', axis = 1)   ####This is for column axis = 1 is for column
# Out:
#    roll      name  marks  age
# 0     1      anil  56.77   22
# 1     2      amit  59.77   21
# 2     3  Ashutosh  76.88   19
# 3     4   ajinkya  69.66   20
# 4     5      asha  63.28   20
# 5     6    ayesha  49.55   20
# 6     7      amar  65.34   19
# 7     8     amita  68.33   23
# 8     9      amol  56.75   20
# 9    10     anmol  78.66   21

# %%
help (df.drop)
# Out:
# Help on method drop in module pandas.core.frame:
#
# drop(labels: 'IndexLabel | None' = None, *, axis: 'Axis' = 0, index: 'IndexLabel | None' = None, columns: 'IndexLabel | None' = None, level: 'Level | None' = None, inplace: 'bool' = False, errors: 'IgnoreRaise' = 'raise') -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by directly specifying index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level. See the :ref:`user guide <advanced.shown_levels>`
#     for more information about the now unused levels.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop. A tuple will be used as a single
#         label and not treated as a list-like.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
# ...

# %%
df['marks'].mean()
# Out:
# 64.499

# %%
df['marks'].max(), df['marks'].min(), df['marks'].sum(), df['marks'].std()
# Out:
# (78.66, 49.55, 644.9899999999999, 9.207178901994535)

# %%
df.max()
# Out:
# roll         10
# name     ayesha
# class        TE
# marks     78.66
# age          23
# dtype: object

# %%
df.count()
# Out:
# roll     10
# name     10
# class    10
# marks    10
# age      10
# dtype: int64

# %%
df3.dtypes
# Out:
# roll        int64
# name       object
# class      object
# marks     float64
# age       float64
# dtype: object

# %%
df3['age'] = df3['age'].fillna(20)
df3['age'].astype(int)
# Out:
# 0     22
# 1     21
# 2     19
# 3     20
# 4     20
# 5     20
# 6     19
# 7     23
# 8     20
# 9     20
# 10    20
# 11    23
# 12    22
# 13    21
# 14    21
# 15    20
# Name: age, dtype: int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    10 non-null     int64
#  1   name    10 non-null     object
#  2   class   10 non-null     object
#  3   marks   10 non-null     float64
#  4   age     10 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 532.0+ bytes

# %%
DF.DESCRIBE()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[170], line 1
# ----> 1 DF.DESCRIBE()
#
# NameError: name 'DF' is not defined

# %%
df.describe()
# Out:
#            roll      marks        age
# count  10.00000  10.000000  10.000000
# mean    5.50000  64.499000  20.500000
# std     3.02765   9.207179   1.269296
# min     1.00000  49.550000  19.000000
# 25%     3.25000  57.520000  20.000000
# 50%     5.50000  64.310000  20.000000
# 75%     7.75000  69.327500  21.000000
# max    10.00000  78.660000  23.000000

# %% [markdown]
# ##### Custom Column Operations

# %%
df['marks'] /10 + 0.45
# Out:
# 0    6.127
# 1    6.427
# 2    8.138
# 3    7.416
# 4    6.778
# 5    5.405
# 6    6.984
# 7    7.283
# 8    6.125
# 9    8.316
# Name: marks, dtype: float64

# %%
df['marks'] = df['marks'] + 0.5

# %%
df
# Out:
#    roll      name class  marks  age
# 0     1      anil    TE  57.27   22
# 1     2      amit    TE  60.27   21
# 2     3  Ashutosh    BE  77.38   19
# 3     4   ajinkya    TE  70.16   20
# 4     5      asha    TE  63.78   20
# 5     6    ayesha    BE  50.05   20
# 6     7      amar    BE  65.84   19
# 7     8     amita    BE  68.83   23
# 8     9      amol    TE  57.25   20
# 9    10     anmol    BE  79.16   21

# %%
df['cgpa'] = df['marks'] /10 + 0.45

# %%
df
# Out:
#    roll      name class  marks  age   cgpa
# 0     1      anil    TE  57.27   22  6.177
# 1     2      amit    TE  60.27   21  6.477
# 2     3  Ashutosh    BE  77.38   19  8.188
# 3     4   ajinkya    TE  70.16   20  7.466
# 4     5      asha    TE  63.78   20  6.828
# 5     6    ayesha    BE  50.05   20  5.455
# 6     7      amar    BE  65.84   19  7.034
# 7     8     amita    BE  68.83   23  7.333
# 8     9      amol    TE  57.25   20  6.175
# 9    10     anmol    BE  79.16   21  8.366

# %%
Join = Columns to Columns ##one column should be same or common colum
merge
append = concat = structure should be same
connect

# %%
ndf = pd.DataFrame({
    'roll': range(1,11),
    'gender': ['M','M','M','M','M','F','M','F','F','M'],
    'cgpa': df['marks'] / 10 + 0.45
})

# %%
ndf
# Out:
#    roll gender   cgpa
# 0     1      M  6.177
# 1     2      M  6.477
# 2     3      M  8.188
# 3     4      M  7.466
# 4     5      M  6.828
# 5     6      F  5.455
# 6     7      M  7.034
# 7     8      F  7.333
# 8     9      F  6.175
# 9    10      M  8.366

# %%
df = pd.read_csv('student.csv')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
new_df = df.merge(ndf, on='roll')   ### if nothing mentioned in on default it will take first column

# %%
new_df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0     1     anil    TE  56.77   22      M  6.177
# 1     2     amit    TE  59.77   21      M  6.477
# 2     3   aniket    BE  76.88   19      M  8.188
# 3     4  ajinkya    TE  69.66   20      M  7.466
# 4     5     asha    TE  63.28   20      M  6.828
# 5     6   ayesha    BE  49.55   20      F  5.455
# 6     7     amar    BE  65.34   19      M  7.034
# 7     8    amita    BE  68.33   23      F  7.333
# 8     9     amol    TE  56.75   20      F  6.175
# 9    10    anmol    BE  78.66   21      M  8.366

# %%
df1 = pd.read_csv('student5.csv')

# %%
df1
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
pd.concat([df,df1], ignore_index=True)
# Out:
#     roll     name class  marks  age
# 0      1     anil    TE  56.77   22
# 1      2     amit    TE  59.77   21
# 2      3   aniket    BE  76.88   19
# 3      4  ajinkya    TE  69.66   20
# 4      5     asha    TE  63.28   20
# 5      6   ayesha    BE  49.55   20
# 6      7     amar    BE  65.34   19
# 7      8    amita    BE  68.33   23
# 8      9     amol    TE  56.75   20
# 9     10    anmol    BE  78.66   21
# 10     1   surbhi    TE  67.44   23
# 11     2    sujay    TE  74.12   22
# 12     3  subhash    BE  82.44   21
# 13     4   sachin    TE  59.33   21
# 14     5  shalini    TE  63.45   20

# %% [markdown]
# ### Boolean Filtering

# %%
df['marks'] > 60
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: marks, dtype: bool

# %%
mask = df['marks'] > 60

# %%
df[mask]
# Out:
#    roll     name class  marks  age
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21

# %%
x = df[(df['marks'] > 60) & (df['class'] == 'BE')]

# %%
x
# Out:
#    roll    name class  marks  age
# 2     3  aniket    BE  76.88   19
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 9    10   anmol    BE  78.66   21

# %%
##### Export the Data

# %%
x.to_csv('output.csv', index=False)

# %%
name = 'tushar'

# %%
name.capitalize(), name.upper()
# Out:
# ('Tushar', 'TUSHAR')

# %%
df['name'].str.capitalize()
# Out:
# 0       Anil
# 1       Amit
# 2     Aniket
# 3    Ajinkya
# 4       Asha
# 5     Ayesha
# 6       Amar
# 7      Amita
# 8       Amol
# 9      Anmol
# Name: name, dtype: object

# %%
df['name'].str.replace('i','ee')
# Out:
# 0       aneel
# 1       ameet
# 2     aneeket
# 3    ajeenkya
# 4        asha
# 5      ayesha
# 6        amar
# 7      ameeta
# 8        amol
# 9       anmol
# Name: name, dtype: object

# %%
###### Grouping and Aggregation

# %%
Descriptive === What?
Diagnostic ==== Why?
Predictive Analytics === What will Happen?
Prescriptive === Course of Action!

Two types of Data

Qualitative : cant be used in Arithmetic equation
1. Nominal : any general purpose
2. Ordinal : String hai, but can be compared
Quantitative : used in Arithmetic
1. Discrete: Full number, no decimal point
2. Continuous: A value with a decimal point

# %%
df['class'].value_counts()
# Out:
# class
# TE    5
# BE    5
# Name: count, dtype: int64

# %%
gr = df.groupby('class')

# %%
gr.groups
# Out:
# {'BE': [2, 5, 6, 7, 9], 'TE': [0, 1, 3, 4, 8]}

# %%
gr.get_group('TE')
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 8     9     amol    TE  56.75   20

# %%
gr.min()
# Out:
#        roll     name  marks  age
# class
# BE        3     amar  49.55   19
# TE        1  ajinkya  56.75   20
